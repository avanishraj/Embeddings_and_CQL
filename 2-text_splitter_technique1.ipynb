# %%
from langchain_community.document_loaders  import PyPDFLoader
loader = PyPDFLoader("Avanish_Minor_Project_Synopsis.pdf")
docs = loader.load()
type(docs[0])
# Out:
# langchain_core.documents.base.Document

# %%
#### Recursively split text by characters

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 80, chunk_overlap = 50)
text = text_splitter.split_documents(docs)
text
# Out:
# [Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 0}, page_content='Minor Project Synopsis  \non'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 0}, page_content='on \n                       Early Pulse ( AI for Health Tomorrow )'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 0}, page_content='Name:  Avanish Raj Singh  \nEnrollment Number: 05419011721'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 0}, page_content='Under  the supervision  of'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 0}, page_content='Dr. Mahesh Chand'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 0}, page_content='Associate  Professor at  \n   University School of Automation and Robotics'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 0}, page_content='University School of Automation and Robotics'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='INTRODUCTION'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='Healthcare today faces significant challenges, including rising costs, delayed'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='diagnoses, and reactive treatment models that focus on managing illness after'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='models that focus on managing illness after it'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='occurs. These inefficiencies lead to poor health outcomes and a heavy burden on'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='to poor health outcomes and a heavy burden on'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='healthcare providers and patients alike. In response to these issues, there is'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='alike. In response to these issues, there is a'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='growing need for proactive he althcare solutions that emphasize early'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='he althcare solutions that emphasize early detection,'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='personalized health management, and effective interventions.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='This project leverages artificial intelligence (AI) and digital technologies to'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='intelligence (AI) and digital technologies to'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='revolutionize the way healthcare is delivered. The core objective is to provide'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='is delivered. The core objective is to provide'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='users with continuous health monitoring, predictive analytics, and personalized'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='predictive analytics, and personalized'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='recommendations,  empowering them to take control of their health. By using AI'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='to analyze user data, the system can predict health risks, offer tailored'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='system can predict health risks, offer tailored advice, and'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='help users prevent potential diseases before they manifest.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='In addition to serving individual users, the project is expanding to include a'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='comprehensive Admin Dashboard  designed for healthcare providers such as'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='labs and hospitals. This dashboard allows healthcare providers to manage'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='dashboard allows healthcare providers to manage patient'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='appointments, track medical records, and monitor revenue, ensuring a more'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='efficient and streamlined healthcare delivery system.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='The project is not only focused on providing healthcare solutions to'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='only focused on providing healthcare solutions to individuals'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='but also aims to assist healthcare providers in managing their operations more'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='effectively. With features like real -time health tracking, patient data'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='like real -time health tracking, patient data management,'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='and AI -drive n appointment scheduling, the project seeks to transform both'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='scheduling, the project seeks to transform both sides'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='of the healthcare ecosystem —users and providers alike.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='This report will detail the technical aspects, design considerations, and'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='the technical aspects, design considerations, and future'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='enhancements of the project, illustrating how AI can be a powerful tool in'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='illustrating how AI can be a powerful tool in creating'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}, page_content='a healthier, more proactive society.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='PROBLEM STATEMENT'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='The global healthcare system is at a critical juncture, facing significant'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='is at a critical juncture, facing significant challenges'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='driven by inefficiencies, rising costs, and a lack of proactive care. The'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='rising costs, and a lack of proactive care. The traditional'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='reactive approach —where diseases are treated only after they have'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='progressed —has led to numerous issues that affect both patients and healthcare'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='issues that affect both patients and healthcare'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='providers:'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='1. Delayed Diagnosis : Many serious health conditions, such as heart disease,'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='cancer, and diabetes, go undetected until they have advanced, resulting in'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='more complex and costly treatments. Early detection remains a challenge'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='in the current healthcare landscape.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='2. High Healthcare Costs : The expense of treating advanced -stage illnesses'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='is significantly higher than prevention and early intervention. This reactive'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='approach burdens healthcare systems, patients, and insurance providers,'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='making treatment inaccessible for many.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='3. Overburdened Healthcare Providers : Hospitals and clinics are'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='overwhelmed by patients who need urgent care for advanced diseases. The'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='limited capacity for early intervention means that healthcare workers face'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='increased workloads, longer wait times, and reduced patient satisfaction.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='4. Limited Access to Personalized Care : Healthcare services are often'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='generic, without considering the individual’s unique health profile,'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='lifestyle, or medical history. Patients receive treatment that is not tailored'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='to their specific needs, leading to suboptimal outcomes.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='5. Lack of Patient Control and Choice : Patients today have very little'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='control over the selection of healthcare services, particularly when it comes'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='to choosing labs for diagnostic tests. They are unable to easily compare'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='prices or distances to lab centres , often resulting in inconvenient and costly'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content=', often resulting in inconvenient and costly'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='decisions. No platform currently provides a streamlined way for users to'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='make informed decisions based on price  and distance , which can greatly'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 2}, page_content='enhance accessibility and affordability for patients.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='6. Inefficient Health Report Access : After undergoing medical tests,'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='patients often need to revisit labs or hospitals to obtain their results,'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='labs or hospitals to obtain their results, causing'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='unnecessary delays and inconvenience. The lack of seamless, digital access'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='to health records hinders patients from efficiently monitoring th eir health.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='No current platform offers users the ability to analyze and compare their'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='previous health reports with current results , preventing them from'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='tracking progress or identifying potential health risks early on.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='7. Poor Health Outcomes : These systemic issues lead to poor health'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='outcomes, as patients are often treated too late or inefficiently, resulting in'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='treated too late or inefficiently, resulting in'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='higher mortality rates, chronic suffering, and decreased quality of life.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='OBJECTIVE: - The main objective that the health app will focus on is to'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content="transform a patient's experience by dissolving the urgent problems of the"),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='existing healthcare system. For example, this application will:'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='1. Facilitate Early Detection : Enable its users to find and schedule'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='appointments at nearby labs and hospitals, allowing proactive health'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='checks, and diagnosis of possible health issues at the right time.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='2. Healthcare Cost Reduction:  Provide transparent pricing and distance'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='information for diagnostic tests so that patients make informed choices'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='based on considerations of affordability and accessibility.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='3. Tailor Patient Care:  Allow users to compare present health reports with'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content="historical data to be more personally involved in the care of one's health."),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='4. Empowering Patient Control : Enable patients to track and monitor their'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content="medical history, thus giving greater control over one's journey, and"),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='encouraging the patient to take more interest in their care.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='5. Health Outcomes:  Eventually, there will be reduced prevalence of'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='advanced disease which leads to healthier outcomes and improved quality'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='of life through preventive care, timely interventions, and education.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='Achieving these goals will make the app a contributing factor toward an'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='efficient, patient -centered health care system that focuses on early'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='intervention and personalized care and ultimately leads to improved quality'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 3}, page_content='of life for users .'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 4}, page_content='Flow Diagrams  \nSequence Diagram:  \n \n \n \nFlow of Operations:'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 4}, page_content='Flow of Operations:  \n1. Opening the App (User Interaction)'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 4}, page_content='o The User  opens the app and either logs in or registers.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 4}, page_content='o This starts the interaction, and the app displays available features.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='2. Selecting Labs and Booking Appointments'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='o The User  searches for available labs or hospitals for a health \ncheckup.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='o The App sends a request to the Database  for lab or hospital details,'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='such as prices , distances , and available slots .'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='o The Database  returns these details, and the App displays options to'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='the User .'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='o The User  selects a preferred lab/hospital and chooses an available'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='slot for the appointment.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='o The App sends the booking details to the Database  to confirm the'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='appointment.  \n3. Admin Dashboard Interaction'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='o The admin  logs into the Admin Dashboard  and retrieves'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='appointment data from the Database .'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content="o The admin  confirms the user's appointment and updates the"),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='appointment status (e.g., assigns a time slot).'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content="o After confirming, the admin  uploads the user's health report to the"),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='Database  when the checkup is complete.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='4. Health Report Notification and Viewing'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='o Once the health report is uploaded, the User  receives a notification'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='through the App that the report is available.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='o The User  can view the current health report and compare it with'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='previous reports, which are fetched from the Database .'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='5. Tracking and Monitoring Medical History'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='o The App allows the User  to track their medical history by analyzing'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='both the current and historical reports.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='o The App fetches this medical history from the Database  and'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='presents it to the User  for monitoring purposes.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='6. Revenue and Report Management (Admin Side)'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='o The Admin Dashboard  also retrieves data related to revenues and'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 5}, page_content='patient checkups from the Database .'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 6}, page_content='o The Admin  can view summaries of revenue on a daily, weekly, or'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 6}, page_content='monthly basis.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 6}, page_content='7. Many other features like daily life and routines analysis, global health'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 6}, page_content='issues, and SOS etc.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 6}, page_content='PERT  (Programme Evaluation and Review Technique) Chart:'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='SOFTWARE REQUIREMENTS  \n \n1. Frontend (User App)  \n• Framework: Flutter'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='• Framework: Flutter   \no For building cross -platform mobile applications.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='• Programming Language: Dart'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='o Primary language for Flutter app development.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='• API Integration: RESTful APIs with FastAPI'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='o For communicating with backend services and fetching data such as'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='health reports, lab/hospital details, and appointment bookings.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='• User Features:  \no Health report analysis using AI models.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='o Conversational chatbot for health queries.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='o Daily life and routines analysis.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='o Secure user authentication and registration.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='• State Management: Provider/Bloc (or any state management framework in'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='Flutter).  \n2. Backend (User App)  \n• Framework: FastAPI'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='o Lightweight and fast for handling requests from the Flutter app.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='• Programming Language: Python'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='o To build the backend APIs, integrate GenAI models, and handle \nlogic.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='logic.  \n• AI Integration: Generative AI models (AWS Bedrock, if possible)'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='o For health report analysis, conversational chatbot, and daily life'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='insights.  \n• Database: Firebase/Firestore'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='o Cloud NoSQL database for storing user data, health reports,'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 7}, page_content='appointment details, etc.  \n• Authentication: Firebase Authentication / OAuth'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='o Secure login and registration process.  \n3. Admin Dashboard'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='3. Admin Dashboard  \n• Frontend: React.js'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='o For creating a responsive and interactive web interface for the'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='Admin Dashboard.  \n• Backend:'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='• Backend:   \no Spring Boot or Node.js (depending on performance and security'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='needs)  \n▪ Spring Boot: Highly secure and scalable for enterprise -grade'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='admin features like role -based access control (RBAC).'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='▪ Node.js: Alternatively used if lighter and faster API execution \nis needed.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='is needed.  \n• Database :'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='• Database : \no Firestore: Storing appointment details, user data, and lab'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='information.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='o SQL/Relational Database (Optional): For admin -side secure and'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='role-based data storage.  \n• Security Features:'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='o Role -based access control (RBAC) for secure data management.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='o Strong authentication and authorization (OAuth or JWT).'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='• API Integration: REST APIs for communication between the Admin'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='Dashboard and backend services.  \n• Features :'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='• Features : \no Appointment management (confirmations, slot updates).'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='o Health report upload.  \no Revenue tracking.  \n4. Generative AI Integration'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='To provide intelligent services like health report analysis, conversational'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='chatbots, and daily routine/lifestyle analysis, we will be integrating'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='analysis, we will be integrating Generative'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='AI models into the system. These models will help in deriving insights from'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='user data, such as hea lth reports, and offering conversational interaction'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 8}, page_content='capabilities to enhance the user experience. Given the preference for using'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 9}, page_content='gemma2 -9b-it / llama -3.1-8b-instant  or free OpenAI models, we will focus on'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 9}, page_content='leveraging these platforms to build cost -effective, efficient AI solutions.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 9}, page_content='5. Hosting & Infrastructure  \n• Cloud Provider: AWS'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 9}, page_content='o EC2 Instances: For hosting both the Fast  API backend and Admin'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 9}, page_content='Dashboard (Spring Boot/Node.js).'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 9}, page_content='o AWS Bedrock: For deploying Generative AI models if available.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 9}, page_content='• Containerization: Docker'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 9}, page_content='o To package and deploy the Fast API  backend, Spring Boot/Node.js'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 9}, page_content='services in containers, ensuring scalability and portability.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 9}, page_content='• API Gateway: AWS API Gateway  \no Secure and scalable API management.'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 9}, page_content='o Secure and scalable API management.  \n \ngemma2 -9b-it / llama -3.1-8b-'),
#  Document(metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 9}, page_content='gemma2 -9b-it / llama -3.1-8b-\ninstant')]

# %%
print(text[10])
print(text[11])
# Out:
# page_content='models that focus on managing illness after it' metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}
# page_content='occurs. These inefficiencies lead to poor health outcomes and a heavy burden on' metadata={'source': 'Avanish_Minor_Project_Synopsis.pdf', 'page': 1}
